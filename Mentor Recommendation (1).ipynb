# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
file_path = 'Downloads/CLAT_Mentor_Recommendation_Dataset.xlsx'
aspirants_df = pd.read_excel(file_path, sheet_name='Aspirants')
mentors_df = pd.read_excel(file_path, sheet_name='Mentors')

# %%
aspirants_df.head()
# Out:
#   AspirantID        Name  Age       City  \
# 0      A0000  Aspirant_0   16      Delhi
# 1      A0001  Aspirant_1   20      Delhi
# 2      A0002  Aspirant_2   20    Chennai
# 3      A0003  Aspirant_3   17  Hyderabad
# 4      A0004  Aspirant_4   18     Mumbai
#
#                              PreferredSubjects  StudyTimePerDay (hrs)  \
# 0  English, Logical Reasoning, Legal Reasoning                      3
# 1                   GK, Legal Reasoning, Maths                      2
# 2                                        Maths                      3
# 3                 English, Legal Reasoning, GK                      7
# 4                                      English                      2
#
#    EnglishProficiency (1-10)      CurrentPrepStage Preffered College
# 0                          2  Completed Mock Tests         NLU Delhi
# 1                          4          Just Started              NUJS
# 2                          9                Midway            NALSAR
# 3                          7                Midway         NLU Delhi
# 4                          2                Midway             NLSIU

# %%
mentors_df.head()
# Out:
#   MentorID      Name  Rank     City                          StrongSubjects  \
# 0    M0000  Mentor_0   249  Chennai            Legal Reasoning, GK, English
# 1    M0001  Mentor_1   189     Pune  Legal Reasoning, Logical Reasoning, GK
# 2    M0002  Mentor_2   460   Mumbai                  Legal Reasoning, Maths
# 3    M0003  Mentor_3   357   Mumbai                Logical Reasoning, Maths
# 4    M0004  Mentor_4   497  Kolkata            Logical Reasoning, GK, Maths
#
#    AvgMentoringHours/week  EnglishProficiency (1-10) CurrentCollege
# 0                       7                         10    NLU Jodhpur
# 1                       4                          7           NUJS
# 2                       5                          9          NLSIU
# 3                       3                          9           NUJS
# 4                       9                         10          NLSIU

# %%
aspirants_df['Profile'] = (
    aspirants_df['PreferredSubjects'] + " " +
    aspirants_df['City'] + " " +
    aspirants_df['EnglishProficiency (1-10)'].astype(str) + " " +
    aspirants_df['Preffered College'].astype(str)
)

mentors_df['Profile'] = (
    mentors_df['StrongSubjects'] + " " +
    mentors_df['City'] + " " +
    mentors_df['EnglishProficiency (1-10)'].astype(str)+ " " +
    mentors_df['CurrentCollege']
)

# %%
aspirants_df['Profile']
# Out:
# 0      English, Logical Reasoning, Legal Reasoning De...
# 1                GK, Legal Reasoning, Maths Delhi 4 NUJS
# 2                                 Maths Chennai 9 NALSAR
# 3      English, Legal Reasoning, GK Hyderabad 7 NLU D...
# 4                                 English Mumbai 2 NLSIU
#                              ...
# 995                                    GK Delhi 8 NALSAR
# 996    Logical Reasoning, Legal Reasoning Bhopal 4 NA...
# 997     Legal Reasoning, GK, English Mumbai 10 NLU Delhi
# 998      Logical Reasoning, English, Maths Pune 9 NALSAR
# 999                       Legal Reasoning Bhopal 6 NLSIU
# Name: Profile, Length: 1000, dtype: object

# %%
vectorizer = CountVectorizer().fit(aspirants_df['Profile'].tolist() + mentors_df['Profile'].tolist())
aspirant_vectors = vectorizer.transform(aspirants_df['Profile'])
mentor_vectors = vectorizer.transform(mentors_df['Profile'])

# %%
similarity_matrix = cosine_similarity(aspirant_vectors, mentor_vectors)

# %%
recommendations = []

for i, similarities in enumerate(similarity_matrix):
    top_mentors_list = similarities.argsort()[-3:][::-1]  
    top_mentors = mentors_df.iloc[top_mentors_list][['MentorID', 'Name', 'CurrentCollege']]
    aspirant_id = aspirants_df.iloc[i]['AspirantID']
    
    for _, row in top_mentors.iterrows():
        recommendations.append([aspirant_id, row['MentorID'], row['Name'], row['CurrentCollege']])

recommendations_df = pd.DataFrame(recommendations, columns=[
    'AspirantID', 'RecommendedMentorID', 'MentorName', 'MentorCollege'
])

# %%
recommendations
# Out:
# [['A0000', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0000', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0000', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0001', 'M0024', 'Mentor_24', 'NUJS'],
#  ['A0001', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0001', 'M0018', 'Mentor_18', 'NUJS'],
#  ['A0002', 'M0159', 'Mentor_159', 'NALSAR'],
#  ['A0002', 'M0181', 'Mentor_181', 'NALSAR'],
#  ['A0002', 'M0112', 'Mentor_112', 'NALSAR'],
#  ['A0003', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0003', 'M0027', 'Mentor_27', 'NLU Delhi'],
#  ['A0003', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0004', 'M0081', 'Mentor_81', 'NLSIU'],
#  ['A0004', 'M0100', 'Mentor_100', 'NLSIU'],
#  ['A0004', 'M0051', 'Mentor_51', 'NLSIU'],
#  ['A0005', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0005', 'M0122', 'Mentor_122', 'NUJS'],
#  ['A0005', 'M0058', 'Mentor_58', 'NUJS'],
#  ['A0006', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0006', 'M0066', 'Mentor_66', 'NLU Delhi'],
#  ['A0006', 'M0048', 'Mentor_48', 'NLU Delhi'],
#  ['A0007', 'M0085', 'Mentor_85', 'NLU Delhi'],
#  ['A0007', 'M0154', 'Mentor_154', 'NLU Jodhpur'],
#  ['A0007', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0008', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0008', 'M0133', 'Mentor_133', 'NUJS'],
#  ['A0008', 'M0102', 'Mentor_102', 'NUJS'],
#  ['A0009', 'M0037', 'Mentor_37', 'NALSAR'],
#  ['A0009', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0009', 'M0050', 'Mentor_50', 'NALSAR'],
#  ['A0010', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0010', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0010', 'M0140', 'Mentor_140', 'NUJS'],
#  ['A0011', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0011', 'M0056', 'Mentor_56', 'NLU Delhi'],
#  ['A0011', 'M0154', 'Mentor_154', 'NLU Jodhpur'],
#  ['A0012', 'M0090', 'Mentor_90', 'NUJS'],
#  ['A0012', 'M0114', 'Mentor_114', 'NLSIU'],
#  ['A0012', 'M0185', 'Mentor_185', 'NLSIU'],
#  ['A0013', 'M0012', 'Mentor_12', 'NLSIU'],
#  ['A0013', 'M0025', 'Mentor_25', 'NUJS'],
#  ['A0013', 'M0086', 'Mentor_86', 'NLSIU'],
#  ['A0014', 'M0154', 'Mentor_154', 'NLU Jodhpur'],
#  ['A0014', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0014', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0015', 'M0004', 'Mentor_4', 'NLSIU'],
#  ['A0015', 'M0167', 'Mentor_167', 'NLSIU'],
#  ['A0015', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0016', 'M0130', 'Mentor_130', 'NUJS'],
#  ['A0016', 'M0024', 'Mentor_24', 'NUJS'],
#  ['A0016', 'M0018', 'Mentor_18', 'NUJS'],
#  ['A0017', 'M0181', 'Mentor_181', 'NALSAR'],
#  ['A0017', 'M0105', 'Mentor_105', 'NALSAR'],
#  ['A0017', 'M0160', 'Mentor_160', 'NALSAR'],
#  ['A0018', 'M0122', 'Mentor_122', 'NUJS'],
#  ['A0018', 'M0016', 'Mentor_16', 'NUJS'],
#  ['A0018', 'M0142', 'Mentor_142', 'NUJS'],
#  ['A0019', 'M0128', 'Mentor_128', 'NUJS'],
#  ['A0019', 'M0153', 'Mentor_153', 'NUJS'],
#  ['A0019', 'M0057', 'Mentor_57', 'NUJS'],
#  ['A0020', 'M0159', 'Mentor_159', 'NALSAR'],
#  ['A0020', 'M0181', 'Mentor_181', 'NALSAR'],
#  ['A0020', 'M0112', 'Mentor_112', 'NALSAR'],
#  ['A0021', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0021', 'M0066', 'Mentor_66', 'NLU Delhi'],
#  ['A0021', 'M0085', 'Mentor_85', 'NLU Delhi'],
#  ['A0022', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0022', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0022', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0023', 'M0120', 'Mentor_120', 'NLSIU'],
#  ['A0023', 'M0167', 'Mentor_167', 'NLSIU'],
#  ['A0023', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0024', 'M0175', 'Mentor_175', 'NLSIU'],
#  ['A0024', 'M0101', 'Mentor_101', 'NLSIU'],
#  ['A0024', 'M0047', 'Mentor_47', 'NLSIU'],
#  ['A0025', 'M0010', 'Mentor_10', 'NLU Delhi'],
#  ['A0025', 'M0141', 'Mentor_141', 'NLU Delhi'],
#  ['A0025', 'M0084', 'Mentor_84', 'NLU Delhi'],
#  ['A0026', 'M0012', 'Mentor_12', 'NLSIU'],
#  ['A0026', 'M0025', 'Mentor_25', 'NUJS'],
#  ['A0026', 'M0086', 'Mentor_86', 'NLSIU'],
#  ['A0027', 'M0135', 'Mentor_135', 'NUJS'],
#  ['A0027', 'M0096', 'Mentor_96', 'NUJS'],
#  ['A0027', 'M0192', 'Mentor_192', 'NUJS'],
#  ['A0028', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0028', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0028', 'M0183', 'Mentor_183', 'NALSAR'],
#  ['A0029', 'M0130', 'Mentor_130', 'NUJS'],
#  ['A0029', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0029', 'M0144', 'Mentor_144', 'NLSIU'],
#  ['A0030', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0030', 'M0045', 'Mentor_45', 'NALSAR'],
#  ['A0030', 'M0104', 'Mentor_104', 'NALSAR'],
#  ['A0031', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0031', 'M0032', 'Mentor_32', 'NLU Delhi'],
#  ['A0031', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0032', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0032', 'M0024', 'Mentor_24', 'NUJS'],
#  ['A0032', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0033', 'M0194', 'Mentor_194', 'NLU Jodhpur'],
#  ['A0033', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0033', 'M0176', 'Mentor_176', 'NLU Delhi'],
#  ['A0034', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0034', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0034', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0035', 'M0024', 'Mentor_24', 'NUJS'],
#  ['A0035', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0035', 'M0016', 'Mentor_16', 'NUJS'],
#  ['A0036', 'M0102', 'Mentor_102', 'NUJS'],
#  ['A0036', 'M0170', 'Mentor_170', 'NUJS'],
#  ['A0036', 'M0005', 'Mentor_5', 'NUJS'],
#  ['A0037', 'M0166', 'Mentor_166', 'NLU Jodhpur'],
#  ['A0037', 'M0118', 'Mentor_118', 'NLU Jodhpur'],
#  ['A0037', 'M0080', 'Mentor_80', 'NLU Jodhpur'],
#  ['A0038', 'M0196', 'Mentor_196', 'NLU Delhi'],
#  ['A0038', 'M0084', 'Mentor_84', 'NLU Delhi'],
#  ['A0038', 'M0052', 'Mentor_52', 'NLU Delhi'],
#  ['A0039', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0039', 'M0018', 'Mentor_18', 'NUJS'],
#  ['A0039', 'M0028', 'Mentor_28', 'NALSAR'],
#  ['A0040', 'M0086', 'Mentor_86', 'NLSIU'],
#  ['A0040', 'M0002', 'Mentor_2', 'NLSIU'],
#  ['A0040', 'M0073', 'Mentor_73', 'NUJS'],
#  ['A0041', 'M0130', 'Mentor_130', 'NUJS'],
#  ['A0041', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0041', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0042', 'M0028', 'Mentor_28', 'NALSAR'],
#  ['A0042', 'M0053', 'Mentor_53', 'NALSAR'],
#  ['A0042', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0043', 'M0032', 'Mentor_32', 'NLU Delhi'],
#  ['A0043', 'M0006', 'Mentor_6', 'NLU Delhi'],
#  ['A0043', 'M0010', 'Mentor_10', 'NLU Delhi'],
#  ['A0044', 'M0040', 'Mentor_40', 'NLU Delhi'],
#  ['A0044', 'M0066', 'Mentor_66', 'NLU Delhi'],
#  ['A0044', 'M0145', 'Mentor_145', 'NLU Delhi'],
#  ['A0045', 'M0026', 'Mentor_26', 'NLU Jodhpur'],
#  ['A0045', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0045', 'M0000', 'Mentor_0', 'NLU Jodhpur'],
#  ['A0046', 'M0077', 'Mentor_77', 'NLU Delhi'],
#  ['A0046', 'M0085', 'Mentor_85', 'NLU Delhi'],
#  ['A0046', 'M0039', 'Mentor_39', 'NLU Delhi'],
#  ['A0047', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0047', 'M0173', 'Mentor_173', 'NLU Delhi'],
#  ['A0047', 'M0184', 'Mentor_184', 'NLU Jodhpur'],
#  ['A0048', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0048', 'M0002', 'Mentor_2', 'NLSIU'],
#  ['A0048', 'M0113', 'Mentor_113', 'NALSAR'],
#  ['A0049', 'M0140', 'Mentor_140', 'NUJS'],
#  ['A0049', 'M0102', 'Mentor_102', 'NUJS'],
#  ['A0049', 'M0008', 'Mentor_8', 'NUJS'],
#  ['A0050', 'M0097', 'Mentor_97', 'NLU Delhi'],
#  ['A0050', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0050', 'M0027', 'Mentor_27', 'NLU Delhi'],
#  ['A0051', 'M0039', 'Mentor_39', 'NLU Delhi'],
#  ['A0051', 'M0032', 'Mentor_32', 'NLU Delhi'],
#  ['A0051', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0052', 'M0183', 'Mentor_183', 'NALSAR'],
#  ['A0052', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0052', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0053', 'M0015', 'Mentor_15', 'NLSIU'],
#  ['A0053', 'M0086', 'Mentor_86', 'NLSIU'],
#  ['A0053', 'M0198', 'Mentor_198', 'NLSIU'],
#  ['A0054', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0054', 'M0185', 'Mentor_185', 'NLSIU'],
#  ['A0054', 'M0047', 'Mentor_47', 'NLSIU'],
#  ['A0055', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0055', 'M0144', 'Mentor_144', 'NLSIU'],
#  ['A0055', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0056', 'M0053', 'Mentor_53', 'NALSAR'],
#  ['A0056', 'M0032', 'Mentor_32', 'NLU Delhi'],
#  ['A0056', 'M0031', 'Mentor_31', 'NALSAR'],
#  ['A0057', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0057', 'M0199', 'Mentor_199', 'NLU Jodhpur'],
#  ['A0057', 'M0169', 'Mentor_169', 'NLU Jodhpur'],
#  ['A0058', 'M0149', 'Mentor_149', 'NLSIU'],
#  ['A0058', 'M0100', 'Mentor_100', 'NLSIU'],
#  ['A0058', 'M0081', 'Mentor_81', 'NLSIU'],
#  ['A0059', 'M0145', 'Mentor_145', 'NLU Delhi'],
#  ['A0059', 'M0040', 'Mentor_40', 'NLU Delhi'],
#  ['A0059', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0060', 'M0006', 'Mentor_6', 'NLU Delhi'],
#  ['A0060', 'M0118', 'Mentor_118', 'NLU Jodhpur'],
#  ['A0060', 'M0164', 'Mentor_164', 'NLU Jodhpur'],
#  ['A0061', 'M0037', 'Mentor_37', 'NALSAR'],
#  ['A0061', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0061', 'M0009', 'Mentor_9', 'NALSAR'],
#  ['A0062', 'M0179', 'Mentor_179', 'NLSIU'],
#  ['A0062', 'M0047', 'Mentor_47', 'NLSIU'],
#  ['A0062', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0063', 'M0188', 'Mentor_188', 'NLU Delhi'],
#  ['A0063', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0063', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0064', 'M0069', 'Mentor_69', 'NALSAR'],
#  ['A0064', 'M0099', 'Mentor_99', 'NALSAR'],
#  ['A0064', 'M0182', 'Mentor_182', 'NALSAR'],
#  ['A0065', 'M0014', 'Mentor_14', 'NLU Delhi'],
#  ['A0065', 'M0052', 'Mentor_52', 'NLU Delhi'],
#  ['A0065', 'M0145', 'Mentor_145', 'NLU Delhi'],
#  ['A0066', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0066', 'M0004', 'Mentor_4', 'NLSIU'],
#  ['A0066', 'M0072', 'Mentor_72', 'NLSIU'],
#  ['A0067', 'M0076', 'Mentor_76', 'NLU Jodhpur'],
#  ['A0067', 'M0154', 'Mentor_154', 'NLU Jodhpur'],
#  ['A0067', 'M0062', 'Mentor_62', 'NLU Jodhpur'],
#  ['A0068', 'M0073', 'Mentor_73', 'NUJS'],
#  ['A0068', 'M0106', 'Mentor_106', 'NUJS'],
#  ['A0068', 'M0058', 'Mentor_58', 'NUJS'],
#  ['A0069', 'M0168', 'Mentor_168', 'NUJS'],
#  ['A0069', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0069', 'M0183', 'Mentor_183', 'NALSAR'],
#  ['A0070', 'M0198', 'Mentor_198', 'NLSIU'],
#  ['A0070', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0070', 'M0012', 'Mentor_12', 'NLSIU'],
#  ['A0071', 'M0002', 'Mentor_2', 'NLSIU'],
#  ['A0071', 'M0051', 'Mentor_51', 'NLSIU'],
#  ['A0071', 'M0195', 'Mentor_195', 'NLSIU'],
#  ['A0072', 'M0003', 'Mentor_3', 'NUJS'],
#  ['A0072', 'M0135', 'Mentor_135', 'NUJS'],
#  ['A0072', 'M0025', 'Mentor_25', 'NUJS'],
#  ['A0073', 'M0117', 'Mentor_117', 'NLU Jodhpur'],
#  ['A0073', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0073', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0074', 'M0049', 'Mentor_49', 'NLU Jodhpur'],
#  ['A0074', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0074', 'M0131', 'Mentor_131', 'NLU Jodhpur'],
#  ['A0075', 'M0149', 'Mentor_149', 'NLSIU'],
#  ['A0075', 'M0100', 'Mentor_100', 'NLSIU'],
#  ['A0075', 'M0081', 'Mentor_81', 'NLSIU'],
#  ['A0076', 'M0136', 'Mentor_136', 'NLU Jodhpur'],
#  ['A0076', 'M0135', 'Mentor_135', 'NUJS'],
#  ['A0076', 'M0197', 'Mentor_197', 'NLSIU'],
#  ['A0077', 'M0020', 'Mentor_20', 'NLU Delhi'],
#  ['A0077', 'M0173', 'Mentor_173', 'NLU Delhi'],
#  ['A0077', 'M0032', 'Mentor_32', 'NLU Delhi'],
#  ['A0078', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0078', 'M0199', 'Mentor_199', 'NLU Jodhpur'],
#  ['A0078', 'M0117', 'Mentor_117', 'NLU Jodhpur'],
#  ['A0079', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0079', 'M0139', 'Mentor_139', 'NLU Jodhpur'],
#  ['A0079', 'M0146', 'Mentor_146', 'NLU Jodhpur'],
#  ['A0080', 'M0028', 'Mentor_28', 'NALSAR'],
#  ['A0080', 'M0041', 'Mentor_41', 'NALSAR'],
#  ['A0080', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0081', 'M0195', 'Mentor_195', 'NLSIU'],
#  ['A0081', 'M0088', 'Mentor_88', 'NALSAR'],
#  ['A0081', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0082', 'M0178', 'Mentor_178', 'NUJS'],
#  ['A0082', 'M0112', 'Mentor_112', 'NALSAR'],
#  ['A0082', 'M0031', 'Mentor_31', 'NALSAR'],
#  ['A0083', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0083', 'M0198', 'Mentor_198', 'NLSIU'],
#  ['A0083', 'M0012', 'Mentor_12', 'NLSIU'],
#  ['A0084', 'M0125', 'Mentor_125', 'NUJS'],
#  ['A0084', 'M0151', 'Mentor_151', 'NUJS'],
#  ['A0084', 'M0061', 'Mentor_61', 'NUJS'],
#  ['A0085', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0085', 'M0168', 'Mentor_168', 'NUJS'],
#  ['A0085', 'M0130', 'Mentor_130', 'NUJS'],
#  ['A0086', 'M0128', 'Mentor_128', 'NUJS'],
#  ['A0086', 'M0167', 'Mentor_167', 'NLSIU'],
#  ['A0086', 'M0024', 'Mentor_24', 'NUJS'],
#  ['A0087', 'M0164', 'Mentor_164', 'NLU Jodhpur'],
#  ['A0087', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0087', 'M0078', 'Mentor_78', 'NLU Jodhpur'],
#  ['A0088', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0088', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0088', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0089', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0089', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0089', 'M0188', 'Mentor_188', 'NLU Delhi'],
#  ['A0090', 'M0104', 'Mentor_104', 'NALSAR'],
#  ['A0090', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0090', 'M0134', 'Mentor_134', 'NALSAR'],
#  ['A0091', 'M0194', 'Mentor_194', 'NLU Jodhpur'],
#  ['A0091', 'M0131', 'Mentor_131', 'NLU Jodhpur'],
#  ['A0091', 'M0076', 'Mentor_76', 'NLU Jodhpur'],
#  ['A0092', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0092', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0092', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0093', 'M0026', 'Mentor_26', 'NLU Jodhpur'],
#  ['A0093', 'M0166', 'Mentor_166', 'NLU Jodhpur'],
#  ['A0093', 'M0000', 'Mentor_0', 'NLU Jodhpur'],
#  ['A0094', 'M0130', 'Mentor_130', 'NUJS'],
#  ['A0094', 'M0102', 'Mentor_102', 'NUJS'],
#  ['A0094', 'M0140', 'Mentor_140', 'NUJS'],
#  ['A0095', 'M0173', 'Mentor_173', 'NLU Delhi'],
#  ['A0095', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0095', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0096', 'M0056', 'Mentor_56', 'NLU Delhi'],
#  ['A0096', 'M0027', 'Mentor_27', 'NLU Delhi'],
#  ['A0096', 'M0184', 'Mentor_184', 'NLU Jodhpur'],
#  ['A0097', 'M0043', 'Mentor_43', 'NLSIU'],
#  ['A0097', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0097', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0098', 'M0058', 'Mentor_58', 'NUJS'],
#  ['A0098', 'M0178', 'Mentor_178', 'NUJS'],
#  ['A0098', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0099', 'M0101', 'Mentor_101', 'NLSIU'],
#  ['A0099', 'M0093', 'Mentor_93', 'NALSAR'],
#  ['A0099', 'M0172', 'Mentor_172', 'NALSAR'],
#  ['A0100', 'M0133', 'Mentor_133', 'NUJS'],
#  ['A0100', 'M0195', 'Mentor_195', 'NLSIU'],
#  ['A0100', 'M0072', 'Mentor_72', 'NLSIU'],
#  ['A0101', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0101', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0101', 'M0018', 'Mentor_18', 'NUJS'],
#  ['A0102', 'M0051', 'Mentor_51', 'NLSIU'],
#  ['A0102', 'M0038', 'Mentor_38', 'NUJS'],
#  ['A0102', 'M0149', 'Mentor_149', 'NLSIU'],
#  ['A0103', 'M0127', 'Mentor_127', 'NLU Jodhpur'],
#  ['A0103', 'M0194', 'Mentor_194', 'NLU Jodhpur'],
#  ['A0103', 'M0048', 'Mentor_48', 'NLU Delhi'],
#  ['A0104', 'M0037', 'Mentor_37', 'NALSAR'],
#  ['A0104', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0104', 'M0050', 'Mentor_50', 'NALSAR'],
#  ['A0105', 'M0128', 'Mentor_128', 'NUJS'],
#  ['A0105', 'M0153', 'Mentor_153', 'NUJS'],
#  ['A0105', 'M0057', 'Mentor_57', 'NUJS'],
#  ['A0106', 'M0006', 'Mentor_6', 'NLU Delhi'],
#  ['A0106', 'M0052', 'Mentor_52', 'NLU Delhi'],
#  ['A0106', 'M0165', 'Mentor_165', 'NLU Jodhpur'],
#  ['A0107', 'M0178', 'Mentor_178', 'NUJS'],
#  ['A0107', 'M0016', 'Mentor_16', 'NUJS'],
#  ['A0107', 'M0193', 'Mentor_193', 'NUJS'],
#  ['A0108', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0108', 'M0097', 'Mentor_97', 'NLU Delhi'],
#  ['A0108', 'M0006', 'Mentor_6', 'NLU Delhi'],
#  ['A0109', 'M0178', 'Mentor_178', 'NUJS'],
#  ['A0109', 'M0016', 'Mentor_16', 'NUJS'],
#  ['A0109', 'M0193', 'Mentor_193', 'NUJS'],
#  ['A0110', 'M0071', 'Mentor_71', 'NALSAR'],
#  ['A0110', 'M0069', 'Mentor_69', 'NALSAR'],
#  ['A0110', 'M0031', 'Mentor_31', 'NALSAR'],
#  ['A0111', 'M0120', 'Mentor_120', 'NLSIU'],
#  ['A0111', 'M0167', 'Mentor_167', 'NLSIU'],
#  ['A0111', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0112', 'M0120', 'Mentor_120', 'NLSIU'],
#  ['A0112', 'M0167', 'Mentor_167', 'NLSIU'],
#  ['A0112', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0113', 'M0021', 'Mentor_21', 'NUJS'],
#  ['A0113', 'M0133', 'Mentor_133', 'NUJS'],
#  ['A0113', 'M0005', 'Mentor_5', 'NUJS'],
#  ['A0114', 'M0195', 'Mentor_195', 'NLSIU'],
#  ['A0114', 'M0072', 'Mentor_72', 'NLSIU'],
#  ['A0114', 'M0002', 'Mentor_2', 'NLSIU'],
#  ['A0115', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0115', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0115', 'M0183', 'Mentor_183', 'NALSAR'],
#  ['A0116', 'M0105', 'Mentor_105', 'NALSAR'],
#  ['A0116', 'M0015', 'Mentor_15', 'NLSIU'],
#  ['A0116', 'M0187', 'Mentor_187', 'NLU Jodhpur'],
#  ['A0117', 'M0122', 'Mentor_122', 'NUJS'],
#  ['A0117', 'M0016', 'Mentor_16', 'NUJS'],
#  ['A0117', 'M0142', 'Mentor_142', 'NUJS'],
#  ['A0118', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0118', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0118', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0119', 'M0120', 'Mentor_120', 'NLSIU'],
#  ['A0119', 'M0075', 'Mentor_75', 'NUJS'],
#  ['A0119', 'M0104', 'Mentor_104', 'NALSAR'],
#  ['A0120', 'M0028', 'Mentor_28', 'NALSAR'],
#  ['A0120', 'M0162', 'Mentor_162', 'NLSIU'],
#  ['A0120', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0121', 'M0030', 'Mentor_30', 'NUJS'],
#  ['A0121', 'M0061', 'Mentor_61', 'NUJS'],
#  ['A0121', 'M0121', 'Mentor_121', 'NUJS'],
#  ['A0122', 'M0021', 'Mentor_21', 'NUJS'],
#  ['A0122', 'M0133', 'Mentor_133', 'NUJS'],
#  ['A0122', 'M0005', 'Mentor_5', 'NUJS'],
#  ['A0123', 'M0028', 'Mentor_28', 'NALSAR'],
#  ['A0123', 'M0162', 'Mentor_162', 'NLSIU'],
#  ['A0123', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0124', 'M0180', 'Mentor_180', 'NALSAR'],
#  ['A0124', 'M0105', 'Mentor_105', 'NALSAR'],
#  ['A0124', 'M0045', 'Mentor_45', 'NALSAR'],
#  ['A0125', 'M0179', 'Mentor_179', 'NLSIU'],
#  ['A0125', 'M0185', 'Mentor_185', 'NLSIU'],
#  ['A0125', 'M0149', 'Mentor_149', 'NLSIU'],
#  ['A0126', 'M0026', 'Mentor_26', 'NLU Jodhpur'],
#  ['A0126', 'M0166', 'Mentor_166', 'NLU Jodhpur'],
#  ['A0126', 'M0000', 'Mentor_0', 'NLU Jodhpur'],
#  ['A0127', 'M0066', 'Mentor_66', 'NLU Delhi'],
#  ['A0127', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0127', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0128', 'M0164', 'Mentor_164', 'NLU Jodhpur'],
#  ['A0128', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0128', 'M0165', 'Mentor_165', 'NLU Jodhpur'],
#  ['A0129', 'M0166', 'Mentor_166', 'NLU Jodhpur'],
#  ['A0129', 'M0080', 'Mentor_80', 'NLU Jodhpur'],
#  ['A0129', 'M0127', 'Mentor_127', 'NLU Jodhpur'],
#  ['A0130', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0130', 'M0024', 'Mentor_24', 'NUJS'],
#  ['A0130', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0131', 'M0002', 'Mentor_2', 'NLSIU'],
#  ['A0131', 'M0072', 'Mentor_72', 'NLSIU'],
#  ['A0131', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0132', 'M0142', 'Mentor_142', 'NUJS'],
#  ['A0132', 'M0075', 'Mentor_75', 'NUJS'],
#  ['A0132', 'M0038', 'Mentor_38', 'NUJS'],
#  ['A0133', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0133', 'M0133', 'Mentor_133', 'NUJS'],
#  ['A0133', 'M0008', 'Mentor_8', 'NUJS'],
#  ['A0134', 'M0050', 'Mentor_50', 'NALSAR'],
#  ['A0134', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0134', 'M0045', 'Mentor_45', 'NALSAR'],
#  ['A0135', 'M0070', 'Mentor_70', 'NLSIU'],
#  ['A0135', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0135', 'M0045', 'Mentor_45', 'NALSAR'],
#  ['A0136', 'M0030', 'Mentor_30', 'NUJS'],
#  ['A0136', 'M0061', 'Mentor_61', 'NUJS'],
#  ['A0136', 'M0121', 'Mentor_121', 'NUJS'],
#  ['A0137', 'M0054', 'Mentor_54', 'NLU Delhi'],
#  ['A0137', 'M0077', 'Mentor_77', 'NLU Delhi'],
#  ['A0137', 'M0022', 'Mentor_22', 'NLU Jodhpur'],
#  ['A0138', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0138', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0138', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0139', 'M0122', 'Mentor_122', 'NUJS'],
#  ['A0139', 'M0090', 'Mentor_90', 'NUJS'],
#  ['A0139', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0140', 'M0040', 'Mentor_40', 'NLU Delhi'],
#  ['A0140', 'M0077', 'Mentor_77', 'NLU Delhi'],
#  ['A0140', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0141', 'M0025', 'Mentor_25', 'NUJS'],
#  ['A0141', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0141', 'M0128', 'Mentor_128', 'NUJS'],
#  ['A0142', 'M0139', 'Mentor_139', 'NLU Jodhpur'],
#  ['A0142', 'M0022', 'Mentor_22', 'NLU Jodhpur'],
#  ['A0142', 'M0107', 'Mentor_107', 'NLU Jodhpur'],
#  ['A0143', 'M0040', 'Mentor_40', 'NLU Delhi'],
#  ['A0143', 'M0077', 'Mentor_77', 'NLU Delhi'],
#  ['A0143', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0144', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0144', 'M0110', 'Mentor_110', 'NUJS'],
#  ['A0144', 'M0083', 'Mentor_83', 'NUJS'],
#  ['A0145', 'M0160', 'Mentor_160', 'NALSAR'],
#  ['A0145', 'M0031', 'Mentor_31', 'NALSAR'],
#  ['A0145', 'M0134', 'Mentor_134', 'NALSAR'],
#  ['A0146', 'M0090', 'Mentor_90', 'NUJS'],
#  ['A0146', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0146', 'M0074', 'Mentor_74', 'NUJS'],
#  ['A0147', 'M0067', 'Mentor_67', 'NLU Jodhpur'],
#  ['A0147', 'M0022', 'Mentor_22', 'NLU Jodhpur'],
#  ['A0147', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0148', 'M0002', 'Mentor_2', 'NLSIU'],
#  ['A0148', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0148', 'M0043', 'Mentor_43', 'NLSIU'],
#  ['A0149', 'M0072', 'Mentor_72', 'NLSIU'],
#  ['A0149', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0149', 'M0002', 'Mentor_2', 'NLSIU'],
#  ['A0150', 'M0154', 'Mentor_154', 'NLU Jodhpur'],
#  ['A0150', 'M0076', 'Mentor_76', 'NLU Jodhpur'],
#  ['A0150', 'M0187', 'Mentor_187', 'NLU Jodhpur'],
#  ['A0151', 'M0005', 'Mentor_5', 'NUJS'],
#  ['A0151', 'M0170', 'Mentor_170', 'NUJS'],
#  ['A0151', 'M0102', 'Mentor_102', 'NUJS'],
#  ['A0152', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0152', 'M0054', 'Mentor_54', 'NLU Delhi'],
#  ['A0152', 'M0128', 'Mentor_128', 'NUJS'],
#  ['A0153', 'M0030', 'Mentor_30', 'NUJS'],
#  ['A0153', 'M0061', 'Mentor_61', 'NUJS'],
#  ['A0153', 'M0121', 'Mentor_121', 'NUJS'],
#  ['A0154', 'M0143', 'Mentor_143', 'NLU Jodhpur'],
#  ['A0154', 'M0165', 'Mentor_165', 'NLU Jodhpur'],
#  ['A0154', 'M0118', 'Mentor_118', 'NLU Jodhpur'],
#  ['A0155', 'M0197', 'Mentor_197', 'NLSIU'],
#  ['A0155', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0155', 'M0013', 'Mentor_13', 'NLSIU'],
#  ['A0156', 'M0035', 'Mentor_35', 'NLU Delhi'],
#  ['A0156', 'M0006', 'Mentor_6', 'NLU Delhi'],
#  ['A0156', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0157', 'M0127', 'Mentor_127', 'NLU Jodhpur'],
#  ['A0157', 'M0194', 'Mentor_194', 'NLU Jodhpur'],
#  ['A0157', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0158', 'M0096', 'Mentor_96', 'NUJS'],
#  ['A0158', 'M0135', 'Mentor_135', 'NUJS'],
#  ['A0158', 'M0155', 'Mentor_155', 'NUJS'],
#  ['A0159', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0159', 'M0062', 'Mentor_62', 'NLU Jodhpur'],
#  ['A0159', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0160', 'M0144', 'Mentor_144', 'NLSIU'],
#  ['A0160', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0160', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0161', 'M0150', 'Mentor_150', 'NALSAR'],
#  ['A0161', 'M0113', 'Mentor_113', 'NALSAR'],
#  ['A0161', 'M0009', 'Mentor_9', 'NALSAR'],
#  ['A0162', 'M0025', 'Mentor_25', 'NUJS'],
#  ['A0162', 'M0096', 'Mentor_96', 'NUJS'],
#  ['A0162', 'M0135', 'Mentor_135', 'NUJS'],
#  ['A0163', 'M0074', 'Mentor_74', 'NUJS'],
#  ['A0163', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0163', 'M0172', 'Mentor_172', 'NALSAR'],
#  ['A0164', 'M0155', 'Mentor_155', 'NUJS'],
#  ['A0164', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0164', 'M0140', 'Mentor_140', 'NUJS'],
#  ['A0165', 'M0118', 'Mentor_118', 'NLU Jodhpur'],
#  ['A0165', 'M0136', 'Mentor_136', 'NLU Jodhpur'],
#  ['A0165', 'M0164', 'Mentor_164', 'NLU Jodhpur'],
#  ['A0166', 'M0058', 'Mentor_58', 'NUJS'],
#  ['A0166', 'M0178', 'Mentor_178', 'NUJS'],
#  ['A0166', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0167', 'M0030', 'Mentor_30', 'NUJS'],
#  ['A0167', 'M0061', 'Mentor_61', 'NUJS'],
#  ['A0167', 'M0121', 'Mentor_121', 'NUJS'],
#  ['A0168', 'M0130', 'Mentor_130', 'NUJS'],
#  ['A0168', 'M0024', 'Mentor_24', 'NUJS'],
#  ['A0168', 'M0018', 'Mentor_18', 'NUJS'],
#  ['A0169', 'M0120', 'Mentor_120', 'NLSIU'],
#  ['A0169', 'M0167', 'Mentor_167', 'NLSIU'],
#  ['A0169', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0170', 'M0159', 'Mentor_159', 'NALSAR'],
#  ['A0170', 'M0179', 'Mentor_179', 'NLSIU'],
#  ['A0170', 'M0104', 'Mentor_104', 'NALSAR'],
#  ['A0171', 'M0172', 'Mentor_172', 'NALSAR'],
#  ['A0171', 'M0074', 'Mentor_74', 'NUJS'],
#  ['A0171', 'M0175', 'Mentor_175', 'NLSIU'],
#  ['A0172', 'M0057', 'Mentor_57', 'NUJS'],
#  ['A0172', 'M0170', 'Mentor_170', 'NUJS'],
#  ['A0172', 'M0111', 'Mentor_111', 'NUJS'],
#  ['A0173', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0173', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0173', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0174', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0174', 'M0188', 'Mentor_188', 'NLU Delhi'],
#  ['A0174', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0175', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0175', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0175', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0176', 'M0127', 'Mentor_127', 'NLU Jodhpur'],
#  ['A0176', 'M0194', 'Mentor_194', 'NLU Jodhpur'],
#  ['A0176', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0177', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0177', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0177', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0178', 'M0047', 'Mentor_47', 'NLSIU'],
#  ['A0178', 'M0012', 'Mentor_12', 'NLSIU'],
#  ['A0178', 'M0198', 'Mentor_198', 'NLSIU'],
#  ['A0179', 'M0121', 'Mentor_121', 'NUJS'],
#  ['A0179', 'M0061', 'Mentor_61', 'NUJS'],
#  ['A0179', 'M0151', 'Mentor_151', 'NUJS'],
#  ['A0180', 'M0117', 'Mentor_117', 'NLU Jodhpur'],
#  ['A0180', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0180', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0181', 'M0128', 'Mentor_128', 'NUJS'],
#  ['A0181', 'M0122', 'Mentor_122', 'NUJS'],
#  ['A0181', 'M0106', 'Mentor_106', 'NUJS'],
#  ['A0182', 'M0172', 'Mentor_172', 'NALSAR'],
#  ['A0182', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0182', 'M0045', 'Mentor_45', 'NALSAR'],
#  ['A0183', 'M0050', 'Mentor_50', 'NALSAR'],
#  ['A0183', 'M0182', 'Mentor_182', 'NALSAR'],
#  ['A0183', 'M0029', 'Mentor_29', 'NLSIU'],
#  ['A0184', 'M0035', 'Mentor_35', 'NLU Delhi'],
#  ['A0184', 'M0048', 'Mentor_48', 'NLU Delhi'],
#  ['A0184', 'M0014', 'Mentor_14', 'NLU Delhi'],
#  ['A0185', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0185', 'M0019', 'Mentor_19', 'NALSAR'],
#  ['A0185', 'M0083', 'Mentor_83', 'NUJS'],
#  ['A0186', 'M0197', 'Mentor_197', 'NLSIU'],
#  ['A0186', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0186', 'M0013', 'Mentor_13', 'NLSIU'],
#  ['A0187', 'M0145', 'Mentor_145', 'NLU Delhi'],
#  ['A0187', 'M0032', 'Mentor_32', 'NLU Delhi'],
#  ['A0187', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0188', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0188', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0188', 'M0013', 'Mentor_13', 'NLSIU'],
#  ['A0189', 'M0058', 'Mentor_58', 'NUJS'],
#  ['A0189', 'M0096', 'Mentor_96', 'NUJS'],
#  ['A0189', 'M0135', 'Mentor_135', 'NUJS'],
#  ['A0190', 'M0159', 'Mentor_159', 'NALSAR'],
#  ['A0190', 'M0179', 'Mentor_179', 'NLSIU'],
#  ['A0190', 'M0059', 'Mentor_59', 'NLSIU'],
#  ['A0191', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0191', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0191', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0192', 'M0183', 'Mentor_183', 'NALSAR'],
#  ['A0192', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0192', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0193', 'M0069', 'Mentor_69', 'NALSAR'],
#  ['A0193', 'M0009', 'Mentor_9', 'NALSAR'],
#  ['A0193', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0194', 'M0019', 'Mentor_19', 'NALSAR'],
#  ['A0194', 'M0099', 'Mentor_99', 'NALSAR'],
#  ['A0194', 'M0069', 'Mentor_69', 'NALSAR'],
#  ['A0195', 'M0143', 'Mentor_143', 'NLU Jodhpur'],
#  ['A0195', 'M0076', 'Mentor_76', 'NLU Jodhpur'],
#  ['A0195', 'M0154', 'Mentor_154', 'NLU Jodhpur'],
#  ['A0196', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0196', 'M0029', 'Mentor_29', 'NLSIU'],
#  ['A0196', 'M0152', 'Mentor_152', 'NUJS'],
#  ['A0197', 'M0035', 'Mentor_35', 'NLU Delhi'],
#  ['A0197', 'M0176', 'Mentor_176', 'NLU Delhi'],
#  ['A0197', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0198', 'M0131', 'Mentor_131', 'NLU Jodhpur'],
#  ['A0198', 'M0194', 'Mentor_194', 'NLU Jodhpur'],
#  ['A0198', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0199', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0199', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0199', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0200', 'M0197', 'Mentor_197', 'NLSIU'],
#  ['A0200', 'M0096', 'Mentor_96', 'NUJS'],
#  ['A0200', 'M0135', 'Mentor_135', 'NUJS'],
#  ['A0201', 'M0114', 'Mentor_114', 'NLSIU'],
#  ['A0201', 'M0177', 'Mentor_177', 'NLSIU'],
#  ['A0201', 'M0190', 'Mentor_190', 'NLSIU'],
#  ['A0202', 'M0152', 'Mentor_152', 'NUJS'],
#  ['A0202', 'M0130', 'Mentor_130', 'NUJS'],
#  ['A0202', 'M0140', 'Mentor_140', 'NUJS'],
#  ['A0203', 'M0003', 'Mentor_3', 'NUJS'],
#  ['A0203', 'M0106', 'Mentor_106', 'NUJS'],
#  ['A0203', 'M0111', 'Mentor_111', 'NUJS'],
#  ['A0204', 'M0121', 'Mentor_121', 'NUJS'],
#  ['A0204', 'M0061', 'Mentor_61', 'NUJS'],
#  ['A0204', 'M0151', 'Mentor_151', 'NUJS'],
#  ['A0205', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0205', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0205', 'M0163', 'Mentor_163', 'NLU Jodhpur'],
#  ['A0206', 'M0114', 'Mentor_114', 'NLSIU'],
#  ['A0206', 'M0149', 'Mentor_149', 'NLSIU'],
#  ['A0206', 'M0185', 'Mentor_185', 'NLSIU'],
#  ['A0207', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0207', 'M0145', 'Mentor_145', 'NLU Delhi'],
#  ['A0207', 'M0018', 'Mentor_18', 'NUJS'],
#  ['A0208', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0208', 'M0162', 'Mentor_162', 'NLSIU'],
#  ['A0208', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0209', 'M0064', 'Mentor_64', 'NLSIU'],
#  ['A0209', 'M0002', 'Mentor_2', 'NLSIU'],
#  ['A0209', 'M0072', 'Mentor_72', 'NLSIU'],
#  ['A0210', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0210', 'M0188', 'Mentor_188', 'NLU Delhi'],
#  ['A0210', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0211', 'M0007', 'Mentor_7', 'NLU Delhi'],
#  ['A0211', 'M0196', 'Mentor_196', 'NLU Delhi'],
#  ['A0211', 'M0188', 'Mentor_188', 'NLU Delhi'],
#  ['A0212', 'M0104', 'Mentor_104', 'NALSAR'],
#  ['A0212', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0212', 'M0134', 'Mentor_134', 'NALSAR'],
#  ['A0213', 'M0058', 'Mentor_58', 'NUJS'],
#  ['A0213', 'M0125', 'Mentor_125', 'NUJS'],
#  ['A0213', 'M0156', 'Mentor_156', 'NUJS'],
#  ['A0214', 'M0188', 'Mentor_188', 'NLU Delhi'],
#  ['A0214', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0214', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0215', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0215', 'M0097', 'Mentor_97', 'NLU Delhi'],
#  ['A0215', 'M0056', 'Mentor_56', 'NLU Delhi'],
#  ['A0216', 'M0099', 'Mentor_99', 'NALSAR'],
#  ['A0216', 'M0069', 'Mentor_69', 'NALSAR'],
#  ['A0216', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0217', 'M0064', 'Mentor_64', 'NLSIU'],
#  ['A0217', 'M0029', 'Mentor_29', 'NLSIU'],
#  ['A0217', 'M0158', 'Mentor_158', 'NLSIU'],
#  ['A0218', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0218', 'M0144', 'Mentor_144', 'NLSIU'],
#  ['A0218', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0219', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0219', 'M0144', 'Mentor_144', 'NLSIU'],
#  ['A0219', 'M0029', 'Mentor_29', 'NLSIU'],
#  ['A0220', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0220', 'M0180', 'Mentor_180', 'NALSAR'],
#  ['A0220', 'M0019', 'Mentor_19', 'NALSAR'],
#  ['A0221', 'M0131', 'Mentor_131', 'NLU Jodhpur'],
#  ['A0221', 'M0076', 'Mentor_76', 'NLU Jodhpur'],
#  ['A0221', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0222', 'M0012', 'Mentor_12', 'NLSIU'],
#  ['A0222', 'M0198', 'Mentor_198', 'NLSIU'],
#  ['A0222', 'M0089', 'Mentor_89', 'NLSIU'],
#  ['A0223', 'M0077', 'Mentor_77', 'NLU Delhi'],
#  ['A0223', 'M0040', 'Mentor_40', 'NLU Delhi'],
#  ['A0223', 'M0188', 'Mentor_188', 'NLU Delhi'],
#  ['A0224', 'M0143', 'Mentor_143', 'NLU Jodhpur'],
#  ['A0224', 'M0063', 'Mentor_63', 'NLU Jodhpur'],
#  ['A0224', 'M0136', 'Mentor_136', 'NLU Jodhpur'],
#  ['A0225', 'M0079', 'Mentor_79', 'NALSAR'],
#  ['A0225', 'M0019', 'Mentor_19', 'NALSAR'],
#  ['A0225', 'M0099', 'Mentor_99', 'NALSAR'],
#  ['A0226', 'M0015', 'Mentor_15', 'NLSIU'],
#  ['A0226', 'M0086', 'Mentor_86', 'NLSIU'],
#  ['A0226', 'M0198', 'Mentor_198', 'NLSIU'],
#  ['A0227', 'M0173', 'Mentor_173', 'NLU Delhi'],
#  ['A0227', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0227', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0228', 'M0180', 'Mentor_180', 'NALSAR'],
#  ['A0228', 'M0037', 'Mentor_37', 'NALSAR'],
#  ['A0228', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0229', 'M0085', 'Mentor_85', 'NLU Delhi'],
#  ['A0229', 'M0173', 'Mentor_173', 'NLU Delhi'],
#  ['A0229', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0230', 'M0162', 'Mentor_162', 'NLSIU'],
#  ['A0230', 'M0029', 'Mentor_29', 'NLSIU'],
#  ['A0230', 'M0004', 'Mentor_4', 'NLSIU'],
#  ['A0231', 'M0111', 'Mentor_111', 'NUJS'],
#  ['A0231', 'M0057', 'Mentor_57', 'NUJS'],
#  ['A0231', 'M0087', 'Mentor_87', 'NUJS'],
#  ['A0232', 'M0127', 'Mentor_127', 'NLU Jodhpur'],
#  ['A0232', 'M0187', 'Mentor_187', 'NLU Jodhpur'],
#  ['A0232', 'M0049', 'Mentor_49', 'NLU Jodhpur'],
#  ['A0233', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0233', 'M0133', 'Mentor_133', 'NUJS'],
#  ['A0233', 'M0001', 'Mentor_1', 'NUJS'],
#  ['A0234', 'M0016', 'Mentor_16', 'NUJS'],
#  ['A0234', 'M0019', 'Mentor_19', 'NALSAR'],
#  ['A0234', 'M0028', 'Mentor_28', 'NALSAR'],
#  ['A0235', 'M0159', 'Mentor_159', 'NALSAR'],
#  ['A0235', 'M0181', 'Mentor_181', 'NALSAR'],
#  ['A0235', 'M0172', 'Mentor_172', 'NALSAR'],
#  ['A0236', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0236', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0236', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0237', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0237', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0237', 'M0183', 'Mentor_183', 'NALSAR'],
#  ['A0238', 'M0015', 'Mentor_15', 'NLSIU'],
#  ['A0238', 'M0103', 'Mentor_103', 'NLSIU'],
#  ['A0238', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0239', 'M0173', 'Mentor_173', 'NLU Delhi'],
#  ['A0239', 'M0020', 'Mentor_20', 'NLU Delhi'],
#  ['A0239', 'M0035', 'Mentor_35', 'NLU Delhi'],
#  ['A0240', 'M0038', 'Mentor_38', 'NUJS'],
#  ['A0240', 'M0042', 'Mentor_42', 'NLSIU'],
#  ['A0240', 'M0101', 'Mentor_101', 'NLSIU'],
#  ['A0241', 'M0153', 'Mentor_153', 'NUJS'],
#  ['A0241', 'M0135', 'Mentor_135', 'NUJS'],
#  ['A0241', 'M0094', 'Mentor_94', 'NUJS'],
#  ['A0242', 'M0072', 'Mentor_72', 'NLSIU'],
#  ['A0242', 'M0162', 'Mentor_162', 'NLSIU'],
#  ['A0242', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0243', 'M0180', 'Mentor_180', 'NALSAR'],
#  ['A0243', 'M0037', 'Mentor_37', 'NALSAR'],
#  ['A0243', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0244', 'M0105', 'Mentor_105', 'NALSAR'],
#  ['A0244', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0244', 'M0183', 'Mentor_183', 'NALSAR'],
#  ['A0245', 'M0017', 'Mentor_17', 'NALSAR'],
#  ['A0245', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0245', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0246', 'M0069', 'Mentor_69', 'NALSAR'],
#  ['A0246', 'M0099', 'Mentor_99', 'NALSAR'],
#  ['A0246', 'M0182', 'Mentor_182', 'NALSAR'],
#  ['A0247', 'M0131', 'Mentor_131', 'NLU Jodhpur'],
#  ['A0247', 'M0076', 'Mentor_76', 'NLU Jodhpur'],
#  ['A0247', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0248', 'M0015', 'Mentor_15', 'NLSIU'],
#  ['A0248', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0248', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0249', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0249', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0249', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0250', 'M0078', 'Mentor_78', 'NLU Jodhpur'],
#  ['A0250', 'M0006', 'Mentor_6', 'NLU Delhi'],
#  ['A0250', 'M0049', 'Mentor_49', 'NLU Jodhpur'],
#  ['A0251', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0251', 'M0039', 'Mentor_39', 'NLU Delhi'],
#  ['A0251', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0252', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0252', 'M0185', 'Mentor_185', 'NLSIU'],
#  ['A0252', 'M0047', 'Mentor_47', 'NLSIU'],
#  ['A0253', 'M0197', 'Mentor_197', 'NLSIU'],
#  ['A0253', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0253', 'M0013', 'Mentor_13', 'NLSIU'],
#  ['A0254', 'M0021', 'Mentor_21', 'NUJS'],
#  ['A0254', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0254', 'M0151', 'Mentor_151', 'NUJS'],
#  ['A0255', 'M0110', 'Mentor_110', 'NUJS'],
#  ['A0255', 'M0155', 'Mentor_155', 'NUJS'],
#  ['A0255', 'M0083', 'Mentor_83', 'NUJS'],
#  ['A0256', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0256', 'M0030', 'Mentor_30', 'NUJS'],
#  ['A0256', 'M0074', 'Mentor_74', 'NUJS'],
#  ['A0257', 'M0128', 'Mentor_128', 'NUJS'],
#  ['A0257', 'M0018', 'Mentor_18', 'NUJS'],
#  ['A0257', 'M0066', 'Mentor_66', 'NLU Delhi'],
#  ['A0258', 'M0021', 'Mentor_21', 'NUJS'],
#  ['A0258', 'M0192', 'Mentor_192', 'NUJS'],
#  ['A0258', 'M0170', 'Mentor_170', 'NUJS'],
#  ['A0259', 'M0027', 'Mentor_27', 'NLU Delhi'],
#  ['A0259', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0259', 'M0169', 'Mentor_169', 'NLU Jodhpur'],
#  ['A0260', 'M0064', 'Mentor_64', 'NLSIU'],
#  ['A0260', 'M0047', 'Mentor_47', 'NLSIU'],
#  ['A0260', 'M0149', 'Mentor_149', 'NLSIU'],
#  ['A0261', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0261', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0261', 'M0056', 'Mentor_56', 'NLU Delhi'],
#  ['A0262', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0262', 'M0009', 'Mentor_9', 'NALSAR'],
#  ['A0262', 'M0144', 'Mentor_144', 'NLSIU'],
#  ['A0263', 'M0195', 'Mentor_195', 'NLSIU'],
#  ['A0263', 'M0088', 'Mentor_88', 'NALSAR'],
#  ['A0263', 'M0102', 'Mentor_102', 'NUJS'],
#  ['A0264', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0264', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0264', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0265', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0265', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0265', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0266', 'M0019', 'Mentor_19', 'NALSAR'],
#  ['A0266', 'M0079', 'Mentor_79', 'NALSAR'],
#  ['A0266', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0267', 'M0057', 'Mentor_57', 'NUJS'],
#  ['A0267', 'M0087', 'Mentor_87', 'NUJS'],
#  ['A0267', 'M0003', 'Mentor_3', 'NUJS'],
#  ['A0268', 'M0032', 'Mentor_32', 'NLU Delhi'],
#  ['A0268', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0268', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0269', 'M0032', 'Mentor_32', 'NLU Delhi'],
#  ['A0269', 'M0010', 'Mentor_10', 'NLU Delhi'],
#  ['A0269', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0270', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0270', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0270', 'M0045', 'Mentor_45', 'NALSAR'],
#  ['A0271', 'M0149', 'Mentor_149', 'NLSIU'],
#  ['A0271', 'M0114', 'Mentor_114', 'NLSIU'],
#  ['A0271', 'M0058', 'Mentor_58', 'NUJS'],
#  ['A0272', 'M0081', 'Mentor_81', 'NLSIU'],
#  ['A0272', 'M0100', 'Mentor_100', 'NLSIU'],
#  ['A0272', 'M0134', 'Mentor_134', 'NALSAR'],
#  ['A0273', 'M0086', 'Mentor_86', 'NLSIU'],
#  ['A0273', 'M0003', 'Mentor_3', 'NUJS'],
#  ['A0273', 'M0198', 'Mentor_198', 'NLSIU'],
#  ['A0274', 'M0071', 'Mentor_71', 'NALSAR'],
#  ['A0274', 'M0069', 'Mentor_69', 'NALSAR'],
#  ['A0274', 'M0031', 'Mentor_31', 'NALSAR'],
#  ['A0275', 'M0131', 'Mentor_131', 'NLU Jodhpur'],
#  ['A0275', 'M0194', 'Mentor_194', 'NLU Jodhpur'],
#  ['A0275', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0276', 'M0038', 'Mentor_38', 'NUJS'],
#  ['A0276', 'M0042', 'Mentor_42', 'NLSIU'],
#  ['A0276', 'M0101', 'Mentor_101', 'NLSIU'],
#  ['A0277', 'M0129', 'Mentor_129', 'NLU Delhi'],
#  ['A0277', 'M0039', 'Mentor_39', 'NLU Delhi'],
#  ['A0277', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0278', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0278', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0278', 'M0186', 'Mentor_186', 'NLU Delhi'],
#  ['A0279', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0279', 'M0172', 'Mentor_172', 'NALSAR'],
#  ['A0279', 'M0112', 'Mentor_112', 'NALSAR'],
#  ['A0280', 'M0120', 'Mentor_120', 'NLSIU'],
#  ['A0280', 'M0065', 'Mentor_65', 'NLSIU'],
#  ['A0280', 'M0081', 'Mentor_81', 'NLSIU'],
#  ['A0281', 'M0052', 'Mentor_52', 'NLU Delhi'],
#  ['A0281', 'M0035', 'Mentor_35', 'NLU Delhi'],
#  ['A0281', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0282', 'M0159', 'Mentor_159', 'NALSAR'],
#  ['A0282', 'M0181', 'Mentor_181', 'NALSAR'],
#  ['A0282', 'M0079', 'Mentor_79', 'NALSAR'],
#  ['A0283', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0283', 'M0054', 'Mentor_54', 'NLU Delhi'],
#  ['A0283', 'M0027', 'Mentor_27', 'NLU Delhi'],
#  ['A0284', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0284', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0284', 'M0186', 'Mentor_186', 'NLU Delhi'],
#  ['A0285', 'M0081', 'Mentor_81', 'NLSIU'],
#  ['A0285', 'M0100', 'Mentor_100', 'NLSIU'],
#  ['A0285', 'M0134', 'Mentor_134', 'NALSAR'],
#  ['A0286', 'M0027', 'Mentor_27', 'NLU Delhi'],
#  ['A0286', 'M0056', 'Mentor_56', 'NLU Delhi'],
#  ['A0286', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0287', 'M0117', 'Mentor_117', 'NLU Jodhpur'],
#  ['A0287', 'M0000', 'Mentor_0', 'NLU Jodhpur'],
#  ['A0287', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0288', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0288', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0288', 'M0088', 'Mentor_88', 'NALSAR'],
#  ['A0289', 'M0155', 'Mentor_155', 'NUJS'],
#  ['A0289', 'M0162', 'Mentor_162', 'NLSIU'],
#  ['A0289', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0290', 'M0052', 'Mentor_52', 'NLU Delhi'],
#  ['A0290', 'M0035', 'Mentor_35', 'NLU Delhi'],
#  ['A0290', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0291', 'M0147', 'Mentor_147', 'NUJS'],
#  ['A0291', 'M0109', 'Mentor_109', 'NALSAR'],
#  ['A0291', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0292', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0292', 'M0154', 'Mentor_154', 'NLU Jodhpur'],
#  ['A0292', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0293', 'M0043', 'Mentor_43', 'NLSIU'],
#  ['A0293', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0293', 'M0144', 'Mentor_144', 'NLSIU'],
#  ['A0294', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0294', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0294', 'M0056', 'Mentor_56', 'NLU Delhi'],
#  ['A0295', 'M0021', 'Mentor_21', 'NUJS'],
#  ['A0295', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0295', 'M0151', 'Mentor_151', 'NUJS'],
#  ['A0296', 'M0159', 'Mentor_159', 'NALSAR'],
#  ['A0296', 'M0181', 'Mentor_181', 'NALSAR'],
#  ['A0296', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0297', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0297', 'M0158', 'Mentor_158', 'NLSIU'],
#  ['A0297', 'M0060', 'Mentor_60', 'NLSIU'],
#  ['A0298', 'M0124', 'Mentor_124', 'NLSIU'],
#  ['A0298', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0298', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0299', 'M0024', 'Mentor_24', 'NUJS'],
#  ['A0299', 'M0157', 'Mentor_157', 'NUJS'],
#  ['A0299', 'M0123', 'Mentor_123', 'NALSAR'],
#  ['A0300', 'M0062', 'Mentor_62', 'NLU Jodhpur'],
#  ['A0300', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0300', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0301', 'M0115', 'Mentor_115', 'NLU Jodhpur'],
#  ['A0301', 'M0107', 'Mentor_107', 'NLU Jodhpur'],
#  ['A0301', 'M0068', 'Mentor_68', 'NLU Jodhpur'],
#  ['A0302', 'M0179', 'Mentor_179', 'NLSIU'],
#  ['A0302', 'M0072', 'Mentor_72', 'NLSIU'],
#  ['A0302', 'M0047', 'Mentor_47', 'NLSIU'],
#  ['A0303', 'M0124', 'Mentor_124', 'NLSIU'],
#  ['A0303', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0303', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0304', 'M0095', 'Mentor_95', 'NLU Delhi'],
#  ['A0304', 'M0018', 'Mentor_18', 'NUJS'],
#  ['A0304', 'M0097', 'Mentor_97', 'NLU Delhi'],
#  ['A0305', 'M0117', 'Mentor_117', 'NLU Jodhpur'],
#  ['A0305', 'M0062', 'Mentor_62', 'NLU Jodhpur'],
#  ['A0305', 'M0107', 'Mentor_107', 'NLU Jodhpur'],
#  ['A0306', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0306', 'M0184', 'Mentor_184', 'NLU Jodhpur'],
#  ['A0306', 'M0199', 'Mentor_199', 'NLU Jodhpur'],
#  ['A0307', 'M0037', 'Mentor_37', 'NALSAR'],
#  ['A0307', 'M0009', 'Mentor_9', 'NALSAR'],
#  ['A0307', 'M0174', 'Mentor_174', 'NALSAR'],
#  ['A0308', 'M0164', 'Mentor_164', 'NLU Jodhpur'],
#  ['A0308', 'M0118', 'Mentor_118', 'NLU Jodhpur'],
#  ['A0308', 'M0006', 'Mentor_6', 'NLU Delhi'],
#  ['A0309', 'M0168', 'Mentor_168', 'NUJS'],
#  ['A0309', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0309', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0310', 'M0126', 'Mentor_126', 'NLU Delhi'],
#  ['A0310', 'M0039', 'Mentor_39', 'NLU Delhi'],
#  ['A0310', 'M0132', 'Mentor_132', 'NLU Delhi'],
#  ['A0311', 'M0046', 'Mentor_46', 'NLU Jodhpur'],
#  ['A0311', 'M0000', 'Mentor_0', 'NLU Jodhpur'],
#  ['A0311', 'M0117', 'Mentor_117', 'NLU Jodhpur'],
#  ['A0312', 'M0035', 'Mentor_35', 'NLU Delhi'],
#  ['A0312', 'M0176', 'Mentor_176', 'NLU Delhi'],
#  ['A0312', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0313', 'M0091', 'Mentor_91', 'NLSIU'],
#  ['A0313', 'M0070', 'Mentor_70', 'NLSIU'],
#  ['A0313', 'M0158', 'Mentor_158', 'NLSIU'],
#  ['A0314', 'M0113', 'Mentor_113', 'NALSAR'],
#  ['A0314', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0314', 'M0170', 'Mentor_170', 'NUJS'],
#  ['A0315', 'M0193', 'Mentor_193', 'NUJS'],
#  ['A0315', 'M0016', 'Mentor_16', 'NUJS'],
#  ['A0315', 'M0152', 'Mentor_152', 'NUJS'],
#  ['A0316', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0316', 'M0030', 'Mentor_30', 'NUJS'],
#  ['A0316', 'M0074', 'Mentor_74', 'NUJS'],
#  ['A0317', 'M0106', 'Mentor_106', 'NUJS'],
#  ['A0317', 'M0090', 'Mentor_90', 'NUJS'],
#  ['A0317', 'M0073', 'Mentor_73', 'NUJS'],
#  ['A0318', 'M0131', 'Mentor_131', 'NLU Jodhpur'],
#  ['A0318', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0318', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0319', 'M0044', 'Mentor_44', 'NLSIU'],
#  ['A0319', 'M0029', 'Mentor_29', 'NLSIU'],
#  ['A0319', 'M0004', 'Mentor_4', 'NLSIU'],
#  ['A0320', 'M0077', 'Mentor_77', 'NLU Delhi'],
#  ['A0320', 'M0006', 'Mentor_6', 'NLU Delhi'],
#  ['A0320', 'M0033', 'Mentor_33', 'NLU Delhi'],
#  ['A0321', 'M0195', 'Mentor_195', 'NLSIU'],
#  ['A0321', 'M0088', 'Mentor_88', 'NALSAR'],
#  ['A0321', 'M0055', 'Mentor_55', 'NLSIU'],
#  ['A0322', 'M0156', 'Mentor_156', 'NUJS'],
#  ['A0322', 'M0101', 'Mentor_101', 'NLSIU'],
#  ['A0322', 'M0015', 'Mentor_15', 'NLSIU'],
#  ['A0323', 'M0082', 'Mentor_82', 'NLU Jodhpur'],
#  ['A0323', 'M0092', 'Mentor_92', 'NLU Jodhpur'],
#  ['A0323', 'M0034', 'Mentor_34', 'NLU Jodhpur'],
#  ['A0324', 'M0052', 'Mentor_52', 'NLU Delhi'],
#  ['A0324', 'M0035', 'Mentor_35', 'NLU Delhi'],
#  ['A0324', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0325', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0325', 'M0171', 'Mentor_171', 'NALSAR'],
#  ['A0325', 'M0088', 'Mentor_88', 'NALSAR'],
#  ['A0326', 'M0119', 'Mentor_119', 'NUJS'],
#  ['A0326', 'M0030', 'Mentor_30', 'NUJS'],
#  ['A0326', 'M0074', 'Mentor_74', 'NUJS'],
#  ['A0327', 'M0173', 'Mentor_173', 'NLU Delhi'],
#  ['A0327', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0327', 'M0011', 'Mentor_11', 'NLU Delhi'],
#  ['A0328', 'M0036', 'Mentor_36', 'NLU Delhi'],
#  ['A0328', 'M0184', 'Mentor_184', 'NLU Jodhpur'],
#  ['A0328', 'M0056', 'Mentor_56', 'NLU Delhi'],
#  ['A0329', 'M0113', 'Mentor_113', 'NALSAR'],
#  ['A0329', 'M0009', 'Mentor_9', 'NALSAR'],
#  ['A0329', 'M0108', 'Mentor_108', 'NALSAR'],
#  ['A0330', 'M0116', 'Mentor_116', 'NLU Delhi'],
#  ['A0330', 'M0014', 'Mentor_14', 'NLU Delhi'],
#  ['A0330', 'M0194', 'Mentor_194', 'NLU Jodhpur'],
#  ['A0331', 'M0049', 'Mentor_49', 'NLU Jodhpur'],
#  ['A0331', 'M0187', 'Mentor_187', 'NLU Jodhpur'],
#  ['A0331', 'M0166', 'Mentor_166', 'NLU Jodhpur'],
#  ['A0332', 'M0159', 'Mentor_159', 'NALSAR'],
#  ['A0332', 'M0181', 'Mentor_181', 'NALSAR'],
#  ['A0332', 'M0112', 'Mentor_112', 'NALSAR'],
#  ['A0333', 'M0195', 'Mentor_195', 'NLSIU'],
#  ...]
